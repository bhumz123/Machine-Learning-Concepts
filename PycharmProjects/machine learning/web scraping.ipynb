# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get("https://www.ambitionbox.com/salaries",headers=headers).text

# %%
# lxml is for parsing the webpage
soup=BeautifulSoup(webpage,'lxml')

# %%
# prettify is used to get the page in html format for better understanding
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="5; URL='/salaries?bm-verify=AAQAAAAH_____9DjZ3b9Fqoo61CkE4ICq2CWaq91C__bRfe5m4I4Rmw2XKQ8YAUqUnvshPYleUSuD7pSWyWaTZILTL_Bfw9jpgi1MJ5Lgd_25lXP7jrT6XQTd3qSmNszfddGsZ2n_RA7mnQOy-3e__WWtjZCi0CiC0cz_tMb_elpOyPDd3w1w24Ae22wsrDk6XIrzQ5pewQ-NYYJV002dJKhrMACetK4e_eets7P_ejqGVOu0txVBnXhTebdFltEU-pVUZ8q7qB9X1TOd07sVjc'" http-equiv="refresh"/>
#   <title>
#   </title>
#   <script>
#    var i = 1685858163;
#         var j = i + Number("8130" + "1157");
#   </script>
#  </head>
#  <body>
#   <noscript>
#    <iframe src="" style="border: none; height: 100%; width: 100%;">
#    </iframe>
#   </noscript>
#   <script>
#    var xhr = new XMLHttpRequest();
#           xhr.withCredentials = true;
#           xhr.addEventListener("loadend", function() {
#               try {
#                   var data = JSON.parse(xhr.responseText);
#                   if (data.hasOwnProperty('reload')) {
#                       if (data["reload"] == true) {
#                         window.location.replace(window.location.href.replace(/[&?]bm-verify=[^#]*/, ""));
#                         if(window.location.hash){
#                           window.location.reload();
#                         }
#                       }
#                   } else if (data.hasOwnProperty('location')) {
#                       window.location.replace(data["location"]);
#
#                   } else {
#                       window.location.reload();
#                   }
#               } catch (e) {
#                   var data = {}
#                   window.location.reload();
#               }
#           });
#           xhr.open("POST", "/_sec/verify?provider=interstitial", false);
#           xhr.setRequestHeader("Content-Type", "application/json");
#           xhr.send(JSON.stringify({
#               "bm-verify": "",
#               "pow": j
#           }));
#   </script>
#  </body>
# </html>

# %%
soup.find_all()
# Out:
# [<html>
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <meta content="5; URL='/salaries?bm-verify=AAQAAAAH_____9DjZ3b9Fqoo61CkE4ICq2CWaq91C__bRfe5m4I4Rmw2XKQ8YAUqUnvshPYleUSuD7pSWyWaTZILTL_Bfw9jpgi1MJ5Lgd_25lXP7jrT6XQTd3qSmNszfddGsZ2n_RA7mnQOy-3e__WWtjZCi0CiC0cz_tMb_elpOyPDd3w1w24Ae22wsrDk6XIrzQ5pewQ-NYYJV002dJKhrMACetK4e_eets7P_ejqGVOu0txVBnXhTebdFltEU-pVUZ8q7qB9X1TOd07sVjc'" http-equiv="refresh"/>
#  <title> </title>
#  <script>
#          var i = 1685858163;
#          var j = i + Number("8130" + "1157");
#      </script>
#  </head>
#  <body><noscript>
#  <iframe src="" style="border: none; height: 100%; width: 100%;"></iframe>
#  </noscript>
#  <script>
#            var xhr = new XMLHttpRequest();
#            xhr.withCredentials = true;
#            xhr.addEventListener("loadend", function() {
#                try {
#                    var data = JSON.parse(xhr.responseText);
#                    if (data.hasOwnProperty('reload')) {
#                        if (data["reload"] == true) {
#                          window.location.replace(window.location.href.replace(/[&?]bm-verify=[^#]*/, ""));
#                          if(window.location.hash){
#                            window.location.reload();
#                          }
#                        }
#                    } else if (data.hasOwnProperty('location')) {
#                        window.location.replace(data["location"]);
#
#                    } else {
#                        window.location.reload();
#                    }
#                } catch (e) {
#                    var data = {}
#                    window.location.reload();
#                }
#            });
#            xhr.open("POST", "/_sec/verify?provider=interstitial", false);
#            xhr.setRequestHeader("Content-Type", "application/json");
#            xhr.send(JSON.stringify({
#                "bm-verify": "",
#                "pow": j
#            }));
#      </script>
#  </body>
#  </html>,
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <meta content="5; URL='/salaries?bm-verify=AAQAAAAH_____9DjZ3b9Fqoo61CkE4ICq2CWaq91C__bRfe5m4I4Rmw2XKQ8YAUqUnvshPYleUSuD7pSWyWaTZILTL_Bfw9jpgi1MJ5Lgd_25lXP7jrT6XQTd3qSmNszfddGsZ2n_RA7mnQOy-3e__WWtjZCi0CiC0cz_tMb_elpOyPDd3w1w24Ae22wsrDk6XIrzQ5pewQ-NYYJV002dJKhrMACetK4e_eets7P_ejqGVOu0txVBnXhTebdFltEU-pVUZ8q7qB9X1TOd07sVjc'" http-equiv="refresh"/>
#  <title> </title>
#  <script>
#          var i = 1685858163;
#          var j = i + Number("8130" + "1157");
#      </script>
#  </head>,
#  <meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>,
#  <meta content="5; URL='/salaries?bm-verify=AAQAAAAH_____9DjZ3b9Fqoo61CkE4ICq2CWaq91C__bRfe5m4I4Rmw2XKQ8YAUqUnvshPYleUSuD7pSWyWaTZILTL_Bfw9jpgi1MJ5Lgd_25lXP7jrT6XQTd3qSmNszfddGsZ2n_RA7mnQOy-3e__WWtjZCi0CiC0cz_tMb_elpOyPDd3w1w24Ae22wsrDk6XIrzQ5pewQ-NYYJV002dJKhrMACetK4e_eets7P_ejqGVOu0txVBnXhTebdFltEU-pVUZ8q7qB9X1TOd07sVjc'" http-equiv="refresh"/>,
#  <title> </title>,
#  <script>
#          var i = 1685858163;
#          var j = i + Number("8130" + "1157");
#      </script>,
#  <body><noscript>
#  <iframe src="" style="border: none; height: 100%; width: 100%;"></iframe>
#  </noscript>
#  <script>
#            var xhr = new XMLHttpRequest();
#            xhr.withCredentials = true;
#            xhr.addEventListener("loadend", function() {
#                try {
#                    var data = JSON.parse(xhr.responseText);
#                    if (data.hasOwnProperty('reload')) {
#                        if (data["reload"] == true) {
#                          window.location.replace(window.location.href.replace(/[&?]bm-verify=[^#]*/, ""));
#                          if(window.location.hash){
#                            window.location.reload();
#                          }
#                        }
#                    } else if (data.hasOwnProperty('location')) {
#                        window.location.replace(data["location"]);
#
#                    } else {
#                        window.location.reload();
#                    }
#                } catch (e) {
#                    var data = {}
#                    window.location.reload();
#                }
#            });
#            xhr.open("POST", "/_sec/verify?provider=interstitial", false);
#            xhr.setRequestHeader("Content-Type", "application/json");
#            xhr.send(JSON.stringify({
#                "bm-verify": "",
#                "pow": j
#            }));
#      </script>
#  </body>,
#  <noscript>
#  <iframe src="" style="border: none; height: 100%; width: 100%;"></iframe>
#  </noscript>,
#  <iframe src="" style="border: none; height: 100%; width: 100%;"></iframe>,
#  <script>
#            var xhr = new XMLHttpRequest();
#            xhr.withCredentials = true;
#            xhr.addEventListener("loadend", function() {
#                try {
#                    var data = JSON.parse(xhr.responseText);
#                    if (data.hasOwnProperty('reload')) {
#                        if (data["reload"] == true) {
#                          window.location.replace(window.location.href.replace(/[&?]bm-verify=[^#]*/, ""));
#                          if(window.location.hash){
#                            window.location.reload();
#                          }
#                        }
#                    } else if (data.hasOwnProperty('location')) {
#                        window.location.replace(data["location"]);
#
#                    } else {
#                        window.location.reload();
#                    }
#                } catch (e) {
#                    var data = {}
#                    window.location.reload();
#                }
#            });
#            xhr.open("POST", "/_sec/verify?provider=interstitial", false);
#            xhr.setRequestHeader("Content-Type", "application/json");
#            xhr.send(JSON.stringify({
#                "bm-verify": "",
#                "pow": j
#            }));
#      </script>]
